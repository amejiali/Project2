# %%
# Initial imports
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn import preprocessing
import hvplot.pandas
import datetime

# %matplotlib inline

# %%
# Set the random seed for reproducibility
# Note: This is used for model prototyping, but it is good practice to comment this out and run multiple experiments to evaluate your model.
from numpy.random import seed

seed(1)
from tensorflow import random

random.set_seed(2)

# %%
#Reading the .csv files

fb_csv = Path("../Resources/fb_data.csv")
fb_df = pd.read_csv(fb_csv)
fb_df['Date'] = pd.to_datetime(fb_df.Date).dt.date

aapl_csv = Path("../Resources/aapl_data.csv")
aapl_df = pd.read_csv(aapl_csv)
aapl_df['Date'] = pd.to_datetime(aapl_df.Date).dt.date

amzn_csv = Path("../Resources/amzn_data.csv")
amzn_df = pd.read_csv(amzn_csv)
amzn_df['Date'] = pd.to_datetime(amzn_df.Date).dt.date

nflx_csv = Path("../Resources/nflx_data.csv")
nflx_df = pd.read_csv(nflx_csv)
nflx_df['Date'] = pd.to_datetime(nflx_df.Date).dt.date

googl_csv = Path("../Resources/googl_data.csv")
googl_df = pd.read_csv(googl_csv)
googl_df['Date'] = pd.to_datetime(googl_df.Date).dt.date

starting_csv = Path("../Resources/Jan23_2020_data.csv")
starting_df = pd.read_csv(starting_csv)


fb_df.set_index("Date", inplace = True)
aapl_df.set_index("Date", inplace = True)
amzn_df.set_index("Date", inplace = True)
nflx_df.set_index("Date", inplace = True)
googl_df.set_index("Date", inplace = True)

# %%
fb_df_Jan = fb_df.loc[datetime.date(2019, 1, 23):datetime.date(2019, 2, 23)]
aapl_df_Jan = aapl_df.loc[datetime.date(2019, 1, 23):datetime.date(2019, 2, 23)]
amzn_df_Jan = amzn_df.loc[datetime.date(2019, 1, 23):datetime.date(2019, 2, 23)]
nflx_df_Jan = nflx_df.loc[datetime.date(2019, 1, 23):datetime.date(2019, 2, 23)]
googl_df_Jan = googl_df.loc[datetime.date(2019, 1, 23):datetime.date(2019, 2, 23)]

# %%
amzn_df_Jan.tail()
# Out:
#                Open       High      Low      Close   Volume  Volatility  \
# Date
# 2019-02-15  1627.86  1628.9099  1604.50  1607.5299  3972633    0.142576
# 2019-02-19  1601.00  1634.0000  1600.56  1627.4731  3363526    0.157221
# 2019-02-20  1630.00  1634.9300  1610.12  1622.6200  3100443    0.040184
# 2019-02-21  1619.85  1623.5600  1600.91  1619.9000  3294305    0.000000
# 2019-02-22  1623.50  1634.9400  1621.17  1631.1900  2590256    0.034944
#
#             sentiment        RSI
# Date
# 2019-02-15   0.000326  50.286517
# 2019-02-19   0.085708  52.921305
# 2019-02-20   0.031268  52.196334
# 2019-02-21   0.019126  51.768290
# 2019-02-22   0.035308  53.473805

# %%
fb_df_Jan = fb_df_Jan.pct_change()
aapl_df_Jan = aapl_df_Jan.pct_change()
amzn_df_Jan = amzn_df_Jan.pct_change()
nflx_df_Jan = nflx_df_Jan.pct_change()
googl_df_Jan = googl_df_Jan.pct_change()

fb_df_Jan.replace([np.inf, -np.inf], np.nan, inplace=True)
aapl_df_Jan.replace([np.inf, -np.inf], np.nan, inplace=True)
amzn_df_Jan.replace([np.inf, -np.inf], np.nan, inplace=True)
nflx_df_Jan.replace([np.inf, -np.inf], np.nan,inplace=True)
googl_df_Jan.replace([np.inf, -np.inf], np.nan, inplace=True)

fb_df_Jan=fb_df_Jan.fillna(0)
aapl_df_Jan=aapl_df_Jan.fillna(0)
amzn_df_Jan=amzn_df_Jan.fillna(0)
nflx_df_Jan=nflx_df_Jan.fillna(0)
googl_df_Jan=googl_df_Jan.fillna(0)

amzn_df_Jan.tail()
# Out:
#                 Open      High       Low     Close    Volume  Volatility  \
# Date
# 2019-02-15  0.002068 -0.005489 -0.000972 -0.010067  0.079869   36.916386
# 2019-02-19 -0.016500  0.003125 -0.002456  0.012406 -0.153326    0.102717
# 2019-02-20  0.018114  0.000569  0.005973 -0.002982 -0.078216   -0.744408
# 2019-02-21 -0.006227 -0.006954 -0.005720 -0.001676  0.062527   -1.000000
# 2019-02-22  0.002253  0.007009  0.012655  0.006970 -0.213717    0.000000
#
#              sentiment       RSI
# Date
# 2019-02-15   -1.240914 -0.042598
# 2019-02-19  262.289968  0.052396
# 2019-02-20   -0.635177 -0.013699
# 2019-02-21   -0.388314 -0.008201
# 2019-02-22    0.846068  0.032945

# %%
fb_df_Jan.iloc[0] = fb_df.iloc[-1]
aapl_df_Jan.iloc[0] = aapl_df.iloc[-1]
amzn_df_Jan.iloc[0] = amzn_df.iloc[-1]
nflx_df_Jan.iloc[0] = nflx_df.iloc[-1]
googl_df_Jan.iloc[0] = googl_df.iloc[-1]

# %%
fb_df_Jan.iloc[0].Open = starting_df.iloc[0].Open
fb_df_Jan.iloc[0].High = starting_df.iloc[0].High
fb_df_Jan.iloc[0].Low = starting_df.iloc[0].Low
fb_df_Jan.iloc[0].Close = starting_df.iloc[0].Close

aapl_df_Jan.iloc[0].Open = starting_df.iloc[1].Open
aapl_df_Jan.iloc[0].High = starting_df.iloc[1].High
aapl_df_Jan.iloc[0].Low = starting_df.iloc[1].Low
aapl_df_Jan.iloc[0].Close = starting_df.iloc[1].Close

amzn_df_Jan.iloc[0].Open = starting_df.iloc[2].Open
amzn_df_Jan.iloc[0].High = starting_df.iloc[2].High
amzn_df_Jan.iloc[0].Low = starting_df.iloc[2].Low
amzn_df_Jan.iloc[0].Close = starting_df.iloc[2].Close

nflx_df_Jan.iloc[0].Open = starting_df.iloc[3].Open
nflx_df_Jan.iloc[0].High = starting_df.iloc[3].High
nflx_df_Jan.iloc[0].Low = starting_df.iloc[3].Low
nflx_df_Jan.iloc[0].Close = starting_df.iloc[3].Close

googl_df_Jan.iloc[0].Open = starting_df.iloc[4].Open
googl_df_Jan.iloc[0].High = starting_df.iloc[4].High
googl_df_Jan.iloc[0].Low = starting_df.iloc[4].Low
googl_df_Jan.iloc[0].Close = starting_df.iloc[4].Close

# %%
for i in range(len(fb_df_Jan)-1):
    fb_df_Jan.iloc[i+1]["Open"] = fb_df_Jan.iloc[i].Open * (1+fb_df_Jan.iloc[i+1].Open)
    fb_df_Jan.iloc[i+1]["High"] = fb_df_Jan.iloc[i].High * (1+fb_df_Jan.iloc[i+1].High)
    fb_df_Jan.iloc[i+1]["Low"] = fb_df_Jan.iloc[i].Low * (1+fb_df_Jan.iloc[i+1].Low)
    fb_df_Jan.iloc[i+1]["Close"] = fb_df_Jan.iloc[i].Close * (1+fb_df_Jan.iloc[i+1].Close)
    fb_df_Jan.iloc[i+1]["Volume"] = fb_df_Jan.iloc[i].Volume * (1+fb_df_Jan.iloc[i+1].Volume)
    fb_df_Jan.iloc[i+1]["Volatility"] = fb_df_Jan.iloc[i].Volatility * (1+fb_df_Jan.iloc[i+1].Volatility)
    fb_df_Jan.iloc[i+1]["sentiment"] = fb_df_Jan.iloc[i].sentiment * (1+fb_df_Jan.iloc[i+1].sentiment)
    fb_df_Jan.iloc[i+1]["RSI"] = fb_df_Jan.iloc[i].RSI * (1+fb_df_Jan.iloc[i+1].RSI)

# %%
for i in range(len(aapl_df_Jan)-1):
    aapl_df_Jan.iloc[i+1]["Open"] = aapl_df_Jan.iloc[i].Open * (1+aapl_df_Jan.iloc[i+1].Open)
    aapl_df_Jan.iloc[i+1]["High"] = aapl_df_Jan.iloc[i].High * (1+aapl_df_Jan.iloc[i+1].High)
    aapl_df_Jan.iloc[i+1]["Low"] = aapl_df_Jan.iloc[i].Low * (1+aapl_df_Jan.iloc[i+1].Low)
    aapl_df_Jan.iloc[i+1]["Close"] = aapl_df_Jan.iloc[i].Close * (1+aapl_df_Jan.iloc[i+1].Close)
    aapl_df_Jan.iloc[i+1]["Volume"] = aapl_df_Jan.iloc[i].Volume * (1+aapl_df_Jan.iloc[i+1].Volume)
    aapl_df_Jan.iloc[i+1]["Volatility"] = aapl_df_Jan.iloc[i].Volatility * (1+aapl_df_Jan.iloc[i+1].Volatility)
    aapl_df_Jan.iloc[i+1]["sentiment"] = aapl_df_Jan.iloc[i].sentiment * (1+aapl_df_Jan.iloc[i+1].sentiment)
    aapl_df_Jan.iloc[i+1]["RSI"] = aapl_df_Jan.iloc[i].RSI * (1+aapl_df_Jan.iloc[i+1].RSI)

# %%
for i in range(len(amzn_df_Jan)-1):
    amzn_df_Jan.iloc[i+1]["Open"] = amzn_df_Jan.iloc[i].Open * (1+amzn_df_Jan.iloc[i+1].Open)
    amzn_df_Jan.iloc[i+1]["High"] = amzn_df_Jan.iloc[i].High * (1+amzn_df_Jan.iloc[i+1].High)
    amzn_df_Jan.iloc[i+1]["Low"] = amzn_df_Jan.iloc[i].Low * (1+amzn_df_Jan.iloc[i+1].Low)
    amzn_df_Jan.iloc[i+1]["Close"] = amzn_df_Jan.iloc[i].Close * (1+amzn_df_Jan.iloc[i+1].Close)
    amzn_df_Jan.iloc[i+1]["Volume"] = amzn_df_Jan.iloc[i].Volume * (1+amzn_df_Jan.iloc[i+1].Volume)
    amzn_df_Jan.iloc[i+1]["Volatility"] = amzn_df_Jan.iloc[i].Volatility * (1+amzn_df_Jan.iloc[i+1].Volatility)
    amzn_df_Jan.iloc[i+1]["sentiment"] = amzn_df_Jan.iloc[i].sentiment * (1+amzn_df_Jan.iloc[i+1].sentiment)
    amzn_df_Jan.iloc[i+1]["RSI"] = amzn_df_Jan.iloc[i].RSI * (1+amzn_df_Jan.iloc[i+1].RSI)

# %%
for i in range(len(nflx_df_Jan)-1):
    nflx_df_Jan.iloc[i+1]["Open"] = nflx_df_Jan.iloc[i].Open * (1+nflx_df_Jan.iloc[i+1].Open)
    nflx_df_Jan.iloc[i+1]["High"] = nflx_df_Jan.iloc[i].High * (1+nflx_df_Jan.iloc[i+1].High)
    nflx_df_Jan.iloc[i+1]["Low"] = nflx_df_Jan.iloc[i].Low * (1+nflx_df_Jan.iloc[i+1].Low)
    nflx_df_Jan.iloc[i+1]["Close"] = nflx_df_Jan.iloc[i].Close * (1+nflx_df_Jan.iloc[i+1].Close)
    nflx_df_Jan.iloc[i+1]["Volume"] = nflx_df_Jan.iloc[i].Volume * (1+nflx_df_Jan.iloc[i+1].Volume)
    nflx_df_Jan.iloc[i+1]["Volatility"] = nflx_df_Jan.iloc[i].Volatility * (1+nflx_df_Jan.iloc[i+1].Volatility)
    nflx_df_Jan.iloc[i+1]["sentiment"] = nflx_df_Jan.iloc[i].sentiment * (1+nflx_df_Jan.iloc[i+1].sentiment)
    nflx_df_Jan.iloc[i+1]["RSI"] = nflx_df_Jan.iloc[i].RSI * (1+nflx_df_Jan.iloc[i+1].RSI)

# %%
for i in range(len(googl_df_Jan)-1):
    googl_df_Jan.iloc[i+1]["Open"] = googl_df_Jan.iloc[i].Open * (1+googl_df_Jan.iloc[i+1].Open)
    googl_df_Jan.iloc[i+1]["High"] = googl_df_Jan.iloc[i].High * (1+googl_df_Jan.iloc[i+1].High)
    googl_df_Jan.iloc[i+1]["Low"] = googl_df_Jan.iloc[i].Low * (1+googl_df_Jan.iloc[i+1].Low)
    googl_df_Jan.iloc[i+1]["Close"] = googl_df_Jan.iloc[i].Close * (1+googl_df_Jan.iloc[i+1].Close)
    googl_df_Jan.iloc[i+1]["Volume"] = googl_df_Jan.iloc[i].Volume * (1+googl_df_Jan.iloc[i+1].Volume)
    googl_df_Jan.iloc[i+1]["Volatility"] = googl_df_Jan.iloc[i].Volatility * (1+googl_df_Jan.iloc[i+1].Volatility)
    googl_df_Jan.iloc[i+1]["sentiment"] = googl_df_Jan.iloc[i].sentiment * (1+googl_df_Jan.iloc[i+1].sentiment)
    googl_df_Jan.iloc[i+1]["RSI"] = googl_df_Jan.iloc[i].RSI * (1+googl_df_Jan.iloc[i+1].RSI)

# %%
amzn_df_Jan
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2019-01-23  1885.110000  1889.980000  1827.760000  1884.580000  2.138549e+06
# 2019-01-24  1868.125694  1889.782955  1850.192806  1905.791673  1.536929e+06
# 2019-01-25  1901.058400  1919.685013  1884.012602  1921.487390  1.909423e+06
# 2019-01-28  1872.166866  1875.805977  1830.129738  1884.159682  1.929873e+06
# 2019-01-29  1856.969782  1861.415295  1803.631754  1834.118789  1.836796e+06
# 2019-01-30  1846.519653  1912.238804  1836.467938  1923.365809  2.147687e+06
# 2019-01-31  1925.954297  1980.042633  1903.820894  1981.149539  3.507101e+06
# 2019-02-01  1864.403262  1907.803008  1839.109800  1869.897653  4.657740e+06
# 2019-02-04  1847.555559  1881.085601  1829.460769  1877.613082  1.992907e+06
# 2019-02-05  1870.709767  1898.908608  1862.342308  1907.979631  1.731974e+06
# 2019-02-06  1901.912169  1906.890761  1851.956277  1887.884968  1.635463e+06
# ...

# %%
#Scaling all the columns

x = fb_df_Jan.Close.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["Close"] = x_Jan

x = fb_df_Jan.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["Open"] = x_Jan

x = fb_df_Jan.High.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["High"] = x_Jan

x = fb_df_Jan.Low.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["Low"] = x_Jan

x = fb_df_Jan.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["Volume"] = x_Jan

x = fb_df_Jan.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["sentiment"] = x_Jan

x = fb_df_Jan.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
fb_df_Jan["RSI"] = x_Jan

x = aapl_df_Jan.Close.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["Close"] = x_Jan

x = aapl_df_Jan.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["Open"] = x_Jan

x = aapl_df_Jan.High.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["High"] = x_Jan

x = aapl_df_Jan.Low.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["Low"] = x_Jan

x = aapl_df_Jan.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["Volume"] = x_Jan
aapl_df_Jan

x = aapl_df_Jan.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["sentiment"] = x_Jan
aapl_df_Jan

x = aapl_df_Jan.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
aapl_df_Jan["RSI"] = x_Jan

x = amzn_df_Jan.Close.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["Close"] = x_Jan

x = amzn_df_Jan.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["Open"] = x_Jan

x = amzn_df_Jan.High.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["High"] = x_Jan

x = amzn_df_Jan.Low.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["Low"] = x_Jan

x = amzn_df_Jan.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["Volume"] = x_Jan

x = amzn_df_Jan.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["sentiment"] = x_Jan

x = amzn_df_Jan.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
amzn_df_Jan["RSI"] = x_Jan

x = nflx_df_Jan.Close.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["Close"] = x_Jan

x = nflx_df_Jan.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["Open"] = x_Jan

x = nflx_df_Jan.High.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["High"] = x_Jan

x = nflx_df_Jan.Low.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["Low"] = x_Jan

x = nflx_df_Jan.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["Volume"] = x_Jan

x = nflx_df_Jan.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["sentiment"] = x_Jan

x = nflx_df_Jan.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
nflx_df_Jan["RSI"] = x_Jan

x = googl_df_Jan.Close.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["Close"] = x_Jan

x = googl_df_Jan.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["Open"] = x_Jan

x = googl_df_Jan.High.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["High"] = x_Jan

x = googl_df_Jan.Low.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["Low"] = x_Jan

x = googl_df_Jan.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["Volume"] = x_Jan

x = googl_df_Jan.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["sentiment"] = x_Jan

x = googl_df_Jan.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_Jan = min_max_scaler.fit_transform(x)
x_Jan
googl_df_Jan["RSI"] = x_Jan

googl_df_Jan
# Out:
#                 Open      High       Low     Close    Volume  Volatility  \
# Date
# 2019-01-23  0.119401  0.118666  0.025820  0.157435  0.109750    0.012810
# 2019-01-24  0.056748  0.047207  0.066633  0.175509  0.121857    0.005687
# 2019-01-25  0.225551  0.266782  0.429470  0.360976  0.049075    0.013523
# 2019-01-28  0.165634  0.124657  0.143095  0.123476  0.108721    0.031967
# 2019-01-29  0.035575  0.000000  0.000000  0.000000  0.036966    0.028076
# 2019-01-30  0.000000  0.213512  0.176912  0.348067  0.117574    0.064828
# 2019-01-31  0.484949  0.619893  0.653507  0.672650  0.298200    0.061234
# 2019-02-01  0.629699  0.717049  0.803432  0.610746  0.189376    0.010041
# 2019-02-04  0.598156  0.831673  0.857738  0.863097  0.595976    0.152880
# 2019-02-05  0.735417  0.978346  0.959187  1.000000  1.000000    0.244317
# 2019-02-06  1.000000  1.000000  0.871897  0.654454  0.411451    0.147031
# 2019-02-07  0.475875  0.393533  0.459270  0.416795  0.299379    0.037775
# ...

# %%
#Saving data to .csv files
fb_df_Jan.to_csv("../Resources/fb_data_Jan2020.csv", encoding='utf-8')#, index = False)
amzn_df_Jan.to_csv("../Resources/amzn_data_Jan2020.csv", encoding='utf-8')#, index = False)
aapl_df_Jan.to_csv("../Resources/aapl_data_Jan2020.csv", encoding='utf-8')#, index = False)
nflx_df_Jan.to_csv("../Resources/nflx_data_Jan2020.csv", encoding='utf-8')#, index = False)
googl_df_Jan.to_csv("../Resources/googl_data_Jan2020.csv", encoding='utf-8')#, index = False)

# %%
googl_df_Jan.reset_index(inplace=True)
