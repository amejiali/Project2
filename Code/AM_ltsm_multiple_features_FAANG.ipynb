# %%
# Initial imports
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn import preprocessing
import hvplot.pandas

# %matplotlib inline

# %%
# Set the random seed for reproducibility
# Note: This is used for model prototyping, but it is good practice to comment this out and run multiple experiments to evaluate your model.
from numpy.random import seed

seed(1)
from tensorflow import random

random.set_seed(2)

# %%
#Reading the .csv files

fb_csv = Path("../Resources/fb_data.csv")
fb_df = pd.read_csv(fb_csv)
fb_df['Date'] = pd.to_datetime(fb_df.Date).dt.date

aapl_csv = Path("../Resources/aapl_data.csv")
aapl_df = pd.read_csv(aapl_csv)
aapl_df['Date'] = pd.to_datetime(aapl_df.Date).dt.date

amzn_csv = Path("../Resources/amzn_data.csv")
amzn_df = pd.read_csv(amzn_csv)
amzn_df['Date'] = pd.to_datetime(amzn_df.Date).dt.date

nflx_csv = Path("../Resources/nflx_data.csv")
nflx_df = pd.read_csv(nflx_csv)
nflx_df['Date'] = pd.to_datetime(nflx_df.Date).dt.date

googl_csv = Path("../Resources/googl_data.csv")
googl_df = pd.read_csv(googl_csv)
googl_df['Date'] = pd.to_datetime(googl_df.Date).dt.date

fb_df.set_index("Date", inplace = True)
aapl_df.set_index("Date", inplace = True)
amzn_df.set_index("Date", inplace = True)
nflx_df.set_index("Date", inplace = True)
googl_df.set_index("Date", inplace = True)

# %%
fb_df = fb_df.drop(columns=["High", "Low"])
fb_df_scaled = fb_df

aapl_df = aapl_df.drop(columns=["High", "Low"])
aapl_df_scaled = aapl_df

amzn_df = amzn_df.drop(columns=["High", "Low"])
amzn_df_scaled = amzn_df

nflx_df = nflx_df.drop(columns=["High", "Low"])
nflx_df_scaled = nflx_df

googl_df = googl_df.drop(columns=["High", "Low"])
googl_df_scaled = googl_df

# %%
#Scaling all the columns

x = fb_df_scaled.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
fb_df_scaled["Open0_1"] = x_scaled

x = fb_df_scaled.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
fb_df_scaled["Volume"] = x_scaled

x = fb_df_scaled.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
fb_df_scaled["sentiment"] = x_scaled

x = fb_df_scaled.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
fb_df_scaled["RSI"] = x_scaled

fb_df_scaled = fb_df_scaled.drop(columns=["Open"])
#fb_df_scaled.dropna(inplace=True)
fb_df_scaled=fb_df_scaled.fillna(0)

x = aapl_df_scaled.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
aapl_df_scaled["Open0_1"] = x_scaled

x = aapl_df_scaled.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
aapl_df_scaled["Volume"] = x_scaled
aapl_df_scaled

x = aapl_df_scaled.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
aapl_df_scaled["sentiment"] = x_scaled
aapl_df_scaled

x = aapl_df_scaled.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
aapl_df_scaled["RSI"] = x_scaled

aapl_df_scaled = aapl_df_scaled.drop(columns=["Open"])
#aapl_df_scaled.dropna(inplace=True)
aapl_df_scaled=aapl_df_scaled.fillna(0)

x = amzn_df_scaled.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
amzn_df_scaled["Open0_1"] = x_scaled

x = amzn_df_scaled.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
amzn_df_scaled["Volume"] = x_scaled

x = amzn_df_scaled.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
amzn_df_scaled["sentiment"] = x_scaled

x = amzn_df_scaled.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
amzn_df_scaled["RSI"] = x_scaled

amzn_df_scaled = amzn_df_scaled.drop(columns=["Open"])
#amzn_df_scaled.dropna(inplace=True)
amzn_df_scaled=amzn_df_scaled.fillna(0)

x = nflx_df_scaled.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
nflx_df_scaled["Open0_1"] = x_scaled

x = nflx_df_scaled.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
nflx_df_scaled["Volume"] = x_scaled

x = nflx_df_scaled.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
nflx_df_scaled["sentiment"] = x_scaled

x = nflx_df_scaled.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
nflx_df_scaled["RSI"] = x_scaled

nflx_df_scaled = nflx_df_scaled.drop(columns=["Open"])
#nflx_df_scaled.dropna(inplace=True)
nflx_df_scaled=nflx_df_scaled.fillna(0)

x = googl_df_scaled.Open.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
googl_df_scaled["Open0_1"] = x_scaled

x = googl_df_scaled.Volume.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
googl_df_scaled["Volume"] = x_scaled

x = googl_df_scaled.sentiment.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
googl_df_scaled["sentiment"] = x_scaled

x = googl_df_scaled.RSI.values
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
googl_df_scaled["RSI"] = x_scaled

googl_df_scaled = googl_df_scaled.drop(columns=["Open"])
#googl_df_scaled.dropna(inplace=True)
googl_df_scaled=googl_df_scaled.fillna(0)
googl_df_scaled
# Out:
#                Close    Volume  Volatility  sentiment       RSI   Open0_1
# Date
# 2019-01-02  1053.240  0.152773    0.279226   0.262816  0.000000  0.000000
# 2019-01-03  1026.505  0.189410    0.297727   0.321999  0.000000  0.069685
# 2019-01-04  1076.550  0.234292    0.498923   0.419047  0.000000  0.042844
# 2019-01-07  1076.010  0.248849    0.073502   0.524146  0.000000  0.159650
# 2019-01-08  1085.510  0.163034    0.007682   0.760071  0.000000  0.170932
# ...              ...       ...         ...        ...       ...       ...
# 2019-12-24  1344.740  0.015894    0.025493   0.372467  0.663397  0.959056
# 2019-12-26  1362.160  0.074121    0.113546   0.523969  0.790973  0.948189
# 2019-12-27  1354.640  0.063306    0.063423   0.526298  0.701485  1.000000
# 2019-12-30  1340.470  0.057970    0.107363   0.435962  0.554641  0.978652
# 2019-12-31  1338.120  0.038471    0.012810   0.698379  0.532288  0.916241
#
# [252 rows x 6 columns]

# %%
def window_data(df, window, feature_col_number, target_col_number):
    """
    This function accepts the column number for the features (X) and the target (y).
    It chunks the data up with a rolling window of Xt - window to predict Xt.
    It returns two numpy arrays of X and y.
    """
    X = []
    y = []
    for i in range(len(df) - window - 1):
        features = df.iloc[i : (i + window), 1:6].values
        X.append(features)
        target = df.iloc[(i + window), target_col_number]
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Creating the features (X) and target (y) data using the window_data() function.
window_size = 5

feature_column = 0
target_column = 0
X_fb, y_fb = window_data(fb_df_scaled, window_size, feature_column, target_column)
#print (f"X_fb sample values:\n{X_fb[:5]} \n")
#print (f"y_fb sample values:\n{y_fb[:5]}")

X_aapl, y_aapl = window_data(aapl_df_scaled, window_size, feature_column, target_column)
#print (f"X_aapl sample values:\n{X_aapl[:5]} \n")
#print (f"y_aapl sample values:\n{y_aapl[:5]}")

X_amzn, y_amzn = window_data(amzn_df_scaled, window_size, feature_column, target_column)
#print (f"X_amzn sample values:\n{X_amzn[:5]} \n")
#print (f"y_amzn sample values:\n{y_amzn[:5]}")

X_nflx, y_nflx = window_data(nflx_df_scaled, window_size, feature_column, target_column)
#print (f"X_nflx sample values:\n{X_nflx[:5]} \n")
#print (f"y_nflx sample values:\n{y_nflx[:5]}")

X_googl, y_googl = window_data(googl_df_scaled, window_size, feature_column, target_column)
print (f"X_googl sample values:\n{X_googl[:5]} \n")
print (f"y_googl sample values:\n{y_googl[:5]}")
# Out:
# X_googl sample values:
# [[[0.15277328 0.27922631 0.26281589 0.         0.        ]
#   [0.18941024 0.29772725 0.32199852 0.         0.06968527]
#   [0.2342916  0.49892313 0.4190467  0.         0.04284442]
#   [0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]]
#
#  [[0.18941024 0.29772725 0.32199852 0.         0.06968527]
#   [0.2342916  0.49892313 0.4190467  0.         0.04284442]
#   [0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]]
#
#  [[0.2342916  0.49892313 0.4190467  0.         0.04284442]
#   [0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]
#   [0.10625191 0.02998816 0.11774981 0.         0.14174584]]
#
#  [[0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]
#   [0.10625191 0.02998816 0.11774981 0.         0.14174584]
#   [0.13928238 0.07019319 0.4228968  0.         0.12678147]]
#
#  [[0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]
#   [0.10625191 0.02998816 0.11774981 0.         0.14174584]
#   [0.13928238 0.07019319 0.4228968  0.         0.12678147]
#   [0.11461021 0.00389253 0.22467271 0.         0.07761283]]]
#
# y_googl sample values:
# [[1083.22 ]
#  [1078.45 ]
#  [1062.93 ]
#  [1052.845]
#  [1086.06 ]]

# %%
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X_fb))
X_fb_train = X_fb[: split - 1]
X_fb_test = X_fb[split:]
y_fb_train = y_fb[: split - 1]
y_fb_test = y_fb[split:]

X_aapl_train = X_aapl[: split - 1]
X_aapl_test = X_aapl[split:]
y_aapl_train = y_aapl[: split - 1]
y_aapl_test = y_aapl[split:]

X_amzn_train = X_amzn[: split - 1]
X_amzn_test = X_amzn[split:]
y_amzn_train = y_amzn[: split - 1]
y_amzn_test = y_amzn[split:]

X_nflx_train = X_nflx[: split - 1]
X_nflx_test = X_nflx[split:]
y_nflx_train = y_nflx[: split - 1]
y_nflx_test = y_nflx[split:]

X_googl_train = X_googl[: split - 1]
X_googl_test = X_googl[split:]
y_googl_train = y_googl[: split - 1]
y_googl_test = y_googl[split:]

# %%
# Use the MinMaxScaler to scale data between 0 and 1.
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(y_fb)
y_fb_train = scaler.transform(y_fb_train)
y_fb_test = scaler.transform(y_fb_test)

scaler.fit(y_aapl)
y_aapl_train = scaler.transform(y_aapl_train)
y_aapl_test = scaler.transform(y_aapl_test)

scaler.fit(y_amzn)
y_amzn_train = scaler.transform(y_amzn_train)
y_amzn_test = scaler.transform(y_amzn_test)

scaler.fit(y_nflx)
y_nflx_train = scaler.transform(y_nflx_train)
y_nflx_test = scaler.transform(y_nflx_test)

scaler.fit(y_googl)
y_googl_train = scaler.transform(y_googl_train)
y_googl_test = scaler.transform(y_googl_test)

# %%
X_fb_train = X_fb_train.reshape((X_fb_train.shape[0], X_fb_train.shape[1], 5))
X_fb_test = X_fb_test.reshape((X_fb_test.shape[0], X_fb_test.shape[1], 5))
#print (f"X_train sample values:\n{X_fb_train[:5]} \n")
#print (f"X_test sample values:\n{X_fb_test[:5]}")

X_aapl_train = X_aapl_train.reshape((X_aapl_train.shape[0], X_aapl_train.shape[1], 5))
X_aapl_test = X_aapl_test.reshape((X_aapl_test.shape[0], X_aapl_test.shape[1], 5))
#print (f"X_train sample values:\n{X_aapl_train[:5]} \n")
#print (f"X_test sample values:\n{X_aapl_test[:5]}")

X_amzn_train = X_amzn_train.reshape((X_amzn_train.shape[0], X_amzn_train.shape[1], 5))
X_amzn_test = X_amzn_test.reshape((X_amzn_test.shape[0], X_amzn_test.shape[1], 5))
#print (f"X_train sample values:\n{X_amzn_train[:5]} \n")
#print (f"X_test sample values:\n{X_amzn_test[:5]}")

X_nflx_train = X_nflx_train.reshape((X_nflx_train.shape[0], X_nflx_train.shape[1], 5))
X_nflx_test = X_nflx_test.reshape((X_nflx_test.shape[0], X_nflx_test.shape[1], 5))
#print (f"X_train sample values:\n{X_nflx_train[:5]} \n")
#print (f"X_test sample values:\n{X_nflx_test[:5]}")

X_googl_train = X_googl_train.reshape((X_googl_train.shape[0], X_googl_train.shape[1], 5))
X_googl_test = X_googl_test.reshape((X_googl_test.shape[0], X_googl_test.shape[1], 5))
print (f"X_train sample values:\n{X_googl_train[:5]} \n")
print (f"X_test sample values:\n{X_googl_test[:5]}")
# Out:
# X_train sample values:
# [[[0.15277328 0.27922631 0.26281589 0.         0.        ]
#   [0.18941024 0.29772725 0.32199852 0.         0.06968527]
#   [0.2342916  0.49892313 0.4190467  0.         0.04284442]
#   [0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]]
#
#  [[0.18941024 0.29772725 0.32199852 0.         0.06968527]
#   [0.2342916  0.49892313 0.4190467  0.         0.04284442]
#   [0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]]
#
#  [[0.2342916  0.49892313 0.4190467  0.         0.04284442]
#   [0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]
#   [0.10625191 0.02998816 0.11774981 0.         0.14174584]]
#
#  [[0.24884939 0.07350218 0.52414609 0.         0.15964964]
#   [0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]
#   [0.10625191 0.02998816 0.11774981 0.         0.14174584]
#   [0.13928238 0.07019319 0.4228968  0.         0.12678147]]
#
#  [[0.16303446 0.00768151 0.76007102 0.         0.1709323 ]
#   [0.11760959 0.04333437 0.57968104 0.         0.18049287]
#   [0.10625191 0.02998816 0.11774981 0.         0.14174584]
#   [0.13928238 0.07019319 0.4228968  0.         0.12678147]
#   [0.11461021 0.00389253 0.22467271 0.         0.07761283]]]
#
# X_test sample values:
# [[[0.15743185 0.01790251 0.2210064  0.60564477 0.53408551]
#   [0.119158   0.10638012 0.37633327 0.61552206 0.50145487]
#   [0.08609847 0.12327489 0.37010741 0.66976416 0.52538599]
#   [0.16485745 0.12893206 0.59614485 0.73064274 0.58274941]
#   [0.08633137 0.03791943 0.65505777 0.74993513 0.61695368]]
#
#  [[0.119158   0.10638012 0.37633327 0.61552206 0.50145487]
#   [0.08609847 0.12327489 0.37010741 0.66976416 0.52538599]
#   [0.16485745 0.12893206 0.59614485 0.73064274 0.58274941]
#   [0.08633137 0.03791943 0.65505777 0.74993513 0.61695368]
#   [0.04551755 0.00412764 0.74327601 0.690102   0.60344418]]
#
#  [[0.08609847 0.12327489 0.37010741 0.66976416 0.52538599]
#   [0.16485745 0.12893206 0.59614485 0.73064274 0.58274941]
#   [0.08633137 0.03791943 0.65505777 0.74993513 0.61695368]
#   [0.04551755 0.00412764 0.74327601 0.690102   0.60344418]
#   [0.0446598  0.00277264 0.71020177 0.68066175 0.60341449]]
#
#  [[0.16485745 0.12893206 0.59614485 0.73064274 0.58274941]
#   [0.08633137 0.03791943 0.65505777 0.74993513 0.61695368]
#   [0.04551755 0.00412764 0.74327601 0.690102   0.60344418]
#   [0.0446598  0.00277264 0.71020177 0.68066175 0.60341449]
#   [0.02818049 0.01542474 0.60378486 0.69699511 0.60285036]]
#
#  [[0.08633137 0.03791943 0.65505777 0.74993513 0.61695368]
#   [0.04551755 0.00412764 0.74327601 0.690102   0.60344418]
#   [0.0446598  0.00277264 0.71020177 0.68066175 0.60341449]
#   [0.02818049 0.01542474 0.60378486 0.69699511 0.60285036]
#   [0.0335246  0.03507681 0.62958527 0.72387116 0.60902613]]]

# %%
# Import required Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Define the LSTM RNN model.
model_fb = Sequential()

number_units = 5
dropout_fraction = 0.2

# Layer 1
model_fb.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_fb_train.shape[1], 5))
    )
model_fb.add(Dropout(dropout_fraction))
# Layer 2
model_fb.add(LSTM(units=number_units, return_sequences=True))
model_fb.add(Dropout(dropout_fraction))
# Layer 3
model_fb.add(LSTM(units=number_units))
model_fb.add(Dropout(dropout_fraction))
# Output layer
model_fb.add(Dense(1))

model_aapl = Sequential()

# Layer 1
model_aapl.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_aapl_train.shape[1], 5))
    )
model_aapl.add(Dropout(dropout_fraction))
# Layer 2
model_aapl.add(LSTM(units=number_units, return_sequences=True))
model_aapl.add(Dropout(dropout_fraction))
# Layer 3
model_aapl.add(LSTM(units=number_units))
model_aapl.add(Dropout(dropout_fraction))
# Output layer
model_aapl.add(Dense(1))

model_amzn = Sequential()

# Layer 1
model_amzn.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_amzn_train.shape[1], 5))
    )
model_amzn.add(Dropout(dropout_fraction))
# Layer 2
model_amzn.add(LSTM(units=number_units, return_sequences=True))
model_amzn.add(Dropout(dropout_fraction))
# Layer 3
model_amzn.add(LSTM(units=number_units))
model_amzn.add(Dropout(dropout_fraction))
# Output layer
model_amzn.add(Dense(1))

model_nflx = Sequential()

# Layer 1
model_nflx.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_nflx_train.shape[1], 5))
    )
model_nflx.add(Dropout(dropout_fraction))
# Layer 2
model_nflx.add(LSTM(units=number_units, return_sequences=True))
model_nflx.add(Dropout(dropout_fraction))
# Layer 3
model_nflx.add(LSTM(units=number_units))
model_nflx.add(Dropout(dropout_fraction))
# Output layer
model_nflx.add(Dense(1))

model_googl = Sequential()

# Layer 1
model_googl.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_googl_train.shape[1], 5))
    )
model_googl.add(Dropout(dropout_fraction))
# Layer 2
model_googl.add(LSTM(units=number_units, return_sequences=True))
model_googl.add(Dropout(dropout_fraction))
# Layer 3
model_googl.add(LSTM(units=number_units))
model_googl.add(Dropout(dropout_fraction))
# Output layer
model_googl.add(Dense(1))

# %%
# Compile the model
model_fb.compile(optimizer="adam", loss="mean_squared_error")
model_aapl.compile(optimizer="adam", loss="mean_squared_error")
model_amzn.compile(optimizer="adam", loss="mean_squared_error")
model_nflx.compile(optimizer="adam", loss="mean_squared_error")
model_googl.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
model_fb.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 666
# Trainable params: 666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Summarize the model
model_aapl.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 666
# Trainable params: 666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Summarize the model
model_amzn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 5)                 220
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 666
# Trainable params: 666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Summarize the model
model_nflx.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 5)                 220
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 5)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 666
# Trainable params: 666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Summarize the model
model_googl.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 5)                 220
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 5)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 666
# Trainable params: 666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model_fb.fit(X_fb_train, y_fb_train, epochs=75, shuffle=False, batch_size=1, verbose=1)
# Out:
# Train on 171 samples
# Epoch 1/75
# 171/171 [==============================] - 4s 25ms/sample - loss: 0.0367
# Epoch 2/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0490
# Epoch 3/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0414
# Epoch 4/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0375
# Epoch 5/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0397
# Epoch 6/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0381
# Epoch 7/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0408
# Epoch 8/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0336
# Epoch 9/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0374
# Epoch 10/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0342
# Epoch 11/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0378
# Epoch 12/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0350
# Epoch 13/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0323
# Epoch 14/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0314
# Epoch 15/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0254
# Epoch 16/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0230
# Epoch 17/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0255
# Epoch 18/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0250
# Epoch 19/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0236
# Epoch 20/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0185
# Epoch 21/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0208
# Epoch 22/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0187
# Epoch 23/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0173
# Epoch 24/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0156
# Epoch 25/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0154
# Epoch 26/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0153
# Epoch 27/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0177
# Epoch 28/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0128
# Epoch 29/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0155
# Epoch 30/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0146
# Epoch 31/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0139
# Epoch 32/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0153
# Epoch 33/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0124
# Epoch 34/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0132
# Epoch 35/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0126
# Epoch 36/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0117
# Epoch 37/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0121
# Epoch 38/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0129
# Epoch 39/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0109
# Epoch 40/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0117
# Epoch 41/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0115
# Epoch 42/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0096
# Epoch 43/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0108
# Epoch 44/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0116
# Epoch 45/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0128
# Epoch 46/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0110
# Epoch 47/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0106
# Epoch 48/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0116
# Epoch 49/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0095
# Epoch 50/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0123
# Epoch 51/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0091
# Epoch 52/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0102
# Epoch 53/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0108
# Epoch 54/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0096
# Epoch 55/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0095
# Epoch 56/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0084
# Epoch 57/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0096
# Epoch 58/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0115
# Epoch 59/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0092
# Epoch 60/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0104
# Epoch 61/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0095
# Epoch 62/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0106
# Epoch 63/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0090
# Epoch 64/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0113
# Epoch 65/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0091
# Epoch 66/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0095
# Epoch 67/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0104
# Epoch 68/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0104
# Epoch 69/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0098
# Epoch 70/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0087
# Epoch 71/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0103
# Epoch 72/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0087
# Epoch 73/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0103
# Epoch 74/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0097
# Epoch 75/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0088

# %%
# Train the model
model_aapl.fit(X_aapl_train, y_aapl_train, epochs=75, shuffle=False, batch_size=1, verbose=1)
# Out:
# Train on 171 samples
# Epoch 1/75
# 171/171 [==============================] - 3s 20ms/sample - loss: 0.0091
# Epoch 2/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0165
# Epoch 3/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0153
# Epoch 4/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0130
# Epoch 5/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0114
# Epoch 6/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0115
# Epoch 7/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0117
# Epoch 8/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0083
# Epoch 9/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0077
# Epoch 10/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0069
# Epoch 11/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0072
# Epoch 12/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0061
# Epoch 13/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0055
# Epoch 14/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0044
# Epoch 15/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0042
# Epoch 16/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0040
# Epoch 17/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0036
# Epoch 18/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0040
# Epoch 19/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0036
# Epoch 20/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0035
# Epoch 21/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0032
# Epoch 22/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0039
# Epoch 23/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0036
# Epoch 24/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0031
# Epoch 25/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0032
# Epoch 26/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0031
# Epoch 27/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0029
# Epoch 28/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0029
# Epoch 29/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0032
# Epoch 30/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0032
# Epoch 31/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0031
# Epoch 32/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0030
# Epoch 33/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0030
# Epoch 34/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0025
# Epoch 35/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0026
# Epoch 36/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0026
# Epoch 37/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0026
# Epoch 38/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0031
# Epoch 39/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0025
# Epoch 40/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0029
# Epoch 41/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0024
# Epoch 42/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0021
# Epoch 43/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0024
# Epoch 44/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0025
# Epoch 45/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0024
# Epoch 46/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0021
# Epoch 47/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0023
# Epoch 48/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0023
# Epoch 49/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0022
# Epoch 50/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0025
# Epoch 51/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0023
# Epoch 52/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0025
# Epoch 53/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0020
# Epoch 54/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0019
# Epoch 55/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0021
# Epoch 56/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0021
# Epoch 57/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0020
# Epoch 58/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0026
# Epoch 59/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0021
# Epoch 60/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0020
# Epoch 61/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0017
# Epoch 62/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0020
# Epoch 63/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0019
# Epoch 64/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0015
# Epoch 65/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0019
# Epoch 66/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0019
# Epoch 67/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0017
# Epoch 68/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0023
# Epoch 69/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0021
# Epoch 70/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0019
# Epoch 71/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0023
# Epoch 72/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0017
# Epoch 73/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0024
# Epoch 74/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0018
# Epoch 75/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0019

# %%
# Train the model
model_amzn.fit(X_amzn_train, y_amzn_train, epochs=75, shuffle=False, batch_size=1, verbose=1)
# Out:
# Train on 171 samples
# Epoch 1/75
# 171/171 [==============================] - 3s 20ms/sample - loss: 0.0574
# Epoch 2/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0617
# Epoch 3/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0616
# Epoch 4/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0551
# Epoch 5/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0541
# Epoch 6/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0434
# Epoch 7/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0484
# Epoch 8/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0429
# Epoch 9/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0394
# Epoch 10/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0351
# Epoch 11/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0335
# Epoch 12/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0346
# Epoch 13/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0279
# Epoch 14/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0317
# Epoch 15/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0258
# Epoch 16/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0241
# Epoch 17/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0226
# Epoch 18/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0239
# Epoch 19/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0225
# Epoch 20/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0183
# Epoch 21/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0179
# Epoch 22/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0174
# Epoch 23/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0173
# Epoch 24/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0191
# Epoch 25/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0156
# Epoch 26/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0177
# Epoch 27/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0186
# Epoch 28/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0174
# Epoch 29/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0158
# Epoch 30/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0162
# Epoch 31/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0174
# Epoch 32/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0171
# Epoch 33/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0162
# Epoch 34/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0137
# Epoch 35/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0155
# Epoch 36/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0151
# Epoch 37/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0141
# Epoch 38/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0160
# Epoch 39/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0149
# Epoch 40/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0151
# Epoch 41/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0148
# Epoch 42/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0168
# Epoch 43/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0134
# Epoch 44/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0134
# Epoch 45/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0149
# Epoch 46/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0147
# Epoch 47/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0147
# Epoch 48/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0138
# Epoch 49/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0136
# Epoch 50/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0138
# Epoch 51/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0126
# Epoch 52/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0133
# Epoch 53/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0135
# Epoch 54/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0110
# Epoch 55/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0124
# Epoch 56/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0124
# Epoch 57/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0131
# Epoch 58/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0124
# Epoch 59/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0114
# Epoch 60/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0136
# Epoch 61/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0150
# Epoch 62/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0147
# Epoch 63/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0140
# Epoch 64/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0130
# Epoch 65/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0121
# Epoch 66/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0134
# Epoch 67/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0144
# Epoch 68/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0141
# Epoch 69/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0127
# Epoch 70/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0123
# Epoch 71/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0126
# Epoch 72/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0115
# Epoch 73/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0127
# Epoch 74/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0128
# Epoch 75/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0111

# %%
# Train the model
model_nflx.fit(X_nflx_train, y_nflx_train, epochs=75, shuffle=False, batch_size=1, verbose=1)
# Out:
# Train on 171 samples
# Epoch 1/75
# 171/171 [==============================] - 4s 21ms/sample - loss: 0.2386
# Epoch 2/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0649
# Epoch 3/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0528
# Epoch 4/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0504
# Epoch 5/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0402
# Epoch 6/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0329
# Epoch 7/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0335
# Epoch 8/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0316
# Epoch 9/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0325
# Epoch 10/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0270
# Epoch 11/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0300
# Epoch 12/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0229
# Epoch 13/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0250
# Epoch 14/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0266
# Epoch 15/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0216
# Epoch 16/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0216
# Epoch 17/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0223
# Epoch 18/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0222
# Epoch 19/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0244
# Epoch 20/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0180
# Epoch 21/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0201
# Epoch 22/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0192
# Epoch 23/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0186
# Epoch 24/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0189
# Epoch 25/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0179
# Epoch 26/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0159
# Epoch 27/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0180
# Epoch 28/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0151
# Epoch 29/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0183
# Epoch 30/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0178
# Epoch 31/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0189
# Epoch 32/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0196
# Epoch 33/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0159
# Epoch 34/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0153
# Epoch 35/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0149
# Epoch 36/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0151
# Epoch 37/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0151
# Epoch 38/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0148
# Epoch 39/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0134
# Epoch 40/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0143
# Epoch 41/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0138
# Epoch 42/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0127
# Epoch 43/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0136
# Epoch 44/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0128
# Epoch 45/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0137
# Epoch 46/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0136
# Epoch 47/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0137
# Epoch 48/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0126
# Epoch 49/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0126
# Epoch 50/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0124
# Epoch 51/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0137
# Epoch 52/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0129
# Epoch 53/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0124
# Epoch 54/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0129
# Epoch 55/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0123
# Epoch 56/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0128
# Epoch 57/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0112
# Epoch 58/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0111
# Epoch 59/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0118
# Epoch 60/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0117
# Epoch 61/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0114
# Epoch 62/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0113
# Epoch 63/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0119
# Epoch 64/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0112
# Epoch 65/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0114
# Epoch 66/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0110
# Epoch 67/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0108
# Epoch 68/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0101
# Epoch 69/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0109
# Epoch 70/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0112
# Epoch 71/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0105
# Epoch 72/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0103
# Epoch 73/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0113
# Epoch 74/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0113
# Epoch 75/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0103

# %%
# Train the model
model_googl.fit(X_googl_train, y_googl_train, epochs=75, shuffle=False, batch_size=1, verbose=1)
# Out:
# Train on 171 samples
# Epoch 1/75
# 171/171 [==============================] - 4s 21ms/sample - loss: 0.0404
# Epoch 2/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0375
# Epoch 3/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0287
# Epoch 4/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0210
# Epoch 5/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0210
# Epoch 6/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0187
# Epoch 7/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0198
# Epoch 8/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0148
# Epoch 9/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0156
# Epoch 10/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0177
# Epoch 11/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0175
# Epoch 12/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0133
# Epoch 13/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0159
# Epoch 14/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0149
# Epoch 15/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0120
# Epoch 16/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0123
# Epoch 17/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0144
# Epoch 18/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0119
# Epoch 19/75
# 171/171 [==============================] - 1s 7ms/sample - loss: 0.0126
# Epoch 20/75
# 171/171 [==============================] - 1s 8ms/sample - loss: 0.0124
# Epoch 21/75
# 171/171 [==============================] - 2s 12ms/sample - loss: 0.0132
# Epoch 22/75
# 171/171 [==============================] - 1s 8ms/sample - loss: 0.0108
# Epoch 23/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0129
# Epoch 24/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0123
# Epoch 25/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0125
# Epoch 26/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0109
# Epoch 27/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0115
# Epoch 28/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0109
# Epoch 29/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0116
# Epoch 30/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0112
# Epoch 31/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0103
# Epoch 32/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0120
# Epoch 33/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0109
# Epoch 34/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0101
# Epoch 35/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0106
# Epoch 36/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0096
# Epoch 37/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0090
# Epoch 38/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0088
# Epoch 39/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0103
# Epoch 40/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0084
# Epoch 41/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0086
# Epoch 42/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0084
# Epoch 43/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0085
# Epoch 44/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0087
# Epoch 45/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0096
# Epoch 46/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0102
# Epoch 47/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0091
# Epoch 48/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0089
# Epoch 49/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0090
# Epoch 50/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0094
# Epoch 51/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0086
# Epoch 52/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0098
# Epoch 53/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0087
# Epoch 54/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0091
# Epoch 55/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0095
# Epoch 56/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0087
# Epoch 57/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0078
# Epoch 58/75
# 171/171 [==============================] - 1s 5ms/sample - loss: 0.0091
# Epoch 59/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0082
# Epoch 60/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0093
# Epoch 61/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0077
# Epoch 62/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0083
# Epoch 63/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0069
# Epoch 64/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0080
# Epoch 65/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0080
# Epoch 66/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0084
# Epoch 67/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0072
# Epoch 68/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0079
# Epoch 69/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0074
# Epoch 70/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0078
# Epoch 71/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0078
# Epoch 72/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0077
# Epoch 73/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0077
# Epoch 74/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0074
# Epoch 75/75
# 171/171 [==============================] - 1s 6ms/sample - loss: 0.0073

# %%
# Evaluate the model
model_fb.evaluate(X_fb_test, y_fb_test)
# Out:
# 74/74 [==============================] - 1s 10ms/sample - loss: 0.0046
# 0.004581720291360005

# %%
# Evaluate the model
model_aapl.evaluate(X_aapl_test, y_aapl_test)
# Out:
# 74/74 [==============================] - 1s 10ms/sample - loss: 0.0569
# 0.05692291380585851

# %%
# Evaluate the model
model_amzn.evaluate(X_amzn_test, y_amzn_test)
# Out:
# 74/74 [==============================] - 1s 10ms/sample - loss: 0.0178
# 0.017807234808601236

# %%
# Evaluate the model
model_nflx.evaluate(X_nflx_test, y_nflx_test)
# Out:
# 74/74 [==============================] - 1s 10ms/sample - loss: 0.0341
# 0.03414605185389519

# %%
# Evaluate the model
model_googl.evaluate(X_googl_test, y_googl_test)
# Out:
# 74/74 [==============================] - 1s 10ms/sample - loss: 0.0352
# 0.03517955299970266

# %%
# Make some predictions
predicted_fb = model_fb.predict(X_fb_test)

# %%
# Make some predictions
predicted_aapl = model_aapl.predict(X_aapl_test)

# %%
# Make some predictions
predicted_amzn = model_amzn.predict(X_amzn_test)

# %%
# Make some predictions
predicted_nflx = model_nflx.predict(X_nflx_test)

# %%
# Make some predictions
predicted_googl = model_googl.predict(X_googl_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices_fb = scaler.inverse_transform(predicted_fb)
predicted_prices_fb
# Out:
# array([[1260.3274],
#        [1268.7445],
#        [1269.3741],
#        [1267.5651],
#        [1268.7458],
#        [1270.0824],
#        [1266.7246],
#        [1261.0304],
#        [1252.8832],
#        [1243.1051],
#        [1235.9424],
#        [1230.7476],
#        [1221.665 ],
#        [1218.7773],
#        [1223.411 ],
#        [1227.8644],
#        [1229.2831],
#        [1222.2382],
#        [1222.4625],
#        [1223.3884],
#        [1228.9   ],
#        [1237.0692],
#        [1248.8258],
#        [1263.4305],
#        [1276.5828],
#        [1280.426 ],
#        [1287.3604],
#        [1281.7831],
#        [1275.8965],
#        [1276.572 ],
#        [1280.7694],
#        [1287.8124],
#        [1291.5958],
#        [1299.3694],
#        [1303.3798],
#        [1309.8667],
#        [1313.8325],
#        [1317.4259],
#        [1312.9163],
#        [1290.336 ],
#        [1273.4781],
#        [1272.6719],
#        [1276.4524],
#        [1289.6677],
#        [1301.4564],
#        [1310.3289],
#        [1317.6031],
#        [1323.8796],
#        [1328.231 ],
#        [1330.9705],
#        [1332.5956],
#        [1330.6099],
#        [1332.973 ],
#        [1334.4742],
#        [1336.3085],
#        [1335.4576],
#        [1333.7867],
#        [1323.1389],
#        [1321.2528],
#        [1318.2462],
#        [1316.8292],
#        [1316.9005],
#        [1326.0828],
#        [1318.9802],
#        [1305.9135],
#        [1298.4375],
#        [1291.3616],
#        [1289.7495],
#        [1303.925 ],
#        [1322.8604],
#        [1331.3579],
#        [1338.9146],
#        [1343.5385],
#        [1346.1819]], dtype=float32)

# %%
# Recover the original prices instead of the scaled version
predicted_prices_aapl = scaler.inverse_transform(predicted_aapl)
predicted_prices_aapl
# Out:
# array([[1184.9409],
#        [1184.7753],
#        [1185.6829],
#        [1188.2131],
#        [1191.381 ],
#        [1191.2882],
#        [1187.6891],
#        [1186.1957],
#        [1188.6204],
#        [1190.8617],
#        [1191.3739],
#        [1193.2405],
#        [1192.0818],
#        [1189.7275],
#        [1186.8021],
#        [1184.1926],
#        [1181.4225],
#        [1179.8129],
#        [1175.474 ],
#        [1174.6788],
#        [1178.1857],
#        [1179.0032],
#        [1180.2568],
#        [1182.743 ],
#        [1186.2084],
#        [1189.6096],
#        [1194.5712],
#        [1198.1912],
#        [1200.8959],
#        [1203.8184],
#        [1207.8423],
#        [1208.8988],
#        [1208.1521],
#        [1206.0481],
#        [1205.0029],
#        [1206.1134],
#        [1208.6423],
#        [1209.1775],
#        [1210.0762],
#        [1211.8265],
#        [1211.5396],
#        [1211.733 ],
#        [1211.8203],
#        [1212.5387],
#        [1212.3887],
#        [1212.0315],
#        [1212.9061],
#        [1214.5267],
#        [1213.9718],
#        [1213.5474],
#        [1212.3396],
#        [1212.8151],
#        [1213.9639],
#        [1215.0592],
#        [1216.3865],
#        [1216.9746],
#        [1215.235 ],
#        [1213.486 ],
#        [1214.299 ],
#        [1215.6176],
#        [1214.8651],
#        [1215.9116],
#        [1217.123 ],
#        [1216.4644],
#        [1215.7736],
#        [1215.6869],
#        [1216.3495],
#        [1216.1595],
#        [1217.5405],
#        [1217.1978],
#        [1217.223 ],
#        [1218.8162],
#        [1220.3616],
#        [1221.2234]], dtype=float32)

# %%
# Recover the original prices instead of the scaled version
predicted_prices_amzn = scaler.inverse_transform(predicted_amzn)
predicted_prices_amzn
# Out:
# array([[1247.72  ],
#        [1245.9078],
#        [1244.7219],
#        [1239.3224],
#        [1234.0581],
#        [1223.197 ],
#        [1218.3553],
#        [1210.7621],
#        [1206.0052],
#        [1198.5431],
#        [1195.1982],
#        [1190.1688],
#        [1187.5035],
#        [1182.672 ],
#        [1179.0216],
#        [1178.9562],
#        [1173.8881],
#        [1162.3181],
#        [1159.6433],
#        [1151.0574],
#        [1142.4519],
#        [1137.1934],
#        [1144.4108],
#        [1158.0216],
#        [1183.7433],
#        [1203.4022],
#        [1218.4342],
#        [1226.2659],
#        [1225.3934],
#        [1227.8638],
#        [1231.5956],
#        [1222.4402],
#        [1217.5812],
#        [1217.4904],
#        [1215.8114],
#        [1225.7764],
#        [1232.0479],
#        [1238.0325],
#        [1240.7169],
#        [1246.9331],
#        [1240.8275],
#        [1231.9319],
#        [1225.8644],
#        [1217.6665],
#        [1208.7719],
#        [1198.5204],
#        [1192.5455],
#        [1185.2445],
#        [1187.4489],
#        [1188.3975],
#        [1193.8579],
#        [1201.9269],
#        [1215.5204],
#        [1233.6405],
#        [1253.2078],
#        [1260.8884],
#        [1256.4744],
#        [1240.2549],
#        [1223.9789],
#        [1209.7393],
#        [1200.3864],
#        [1197.3055],
#        [1195.052 ],
#        [1195.8748],
#        [1196.3046],
#        [1199.053 ],
#        [1210.5215],
#        [1221.3937],
#        [1233.5583],
#        [1244.9236],
#        [1249.5122],
#        [1248.1073],
#        [1261.3907],
#        [1274.9055]], dtype=float32)

# %%
# Recover the original prices instead of the scaled version
predicted_prices_nflx = scaler.inverse_transform(predicted_nflx)
predicted_prices_nflx
# Out:
# array([[1133.0342],
#        [1129.1401],
#        [1124.0543],
#        [1122.2815],
#        [1123.6157],
#        [1125.967 ],
#        [1134.2222],
#        [1144.0286],
#        [1156.957 ],
#        [1167.539 ],
#        [1145.8064],
#        [1149.5925],
#        [1141.7509],
#        [1136.6685],
#        [1134.0613],
#        [1131.1951],
#        [1130.6423],
#        [1128.384 ],
#        [1128.2357],
#        [1128.5919],
#        [1120.1564],
#        [1120.8264],
#        [1125.8195],
#        [1136.8175],
#        [1116.7819],
#        [1133.1393],
#        [1189.3212],
#        [1250.316 ],
#        [1240.4485],
#        [1198.392 ],
#        [1121.5486],
#        [1119.8157],
#        [1114.5448],
#        [1111.8202],
#        [1110.9712],
#        [1111.982 ],
#        [1118.1945],
#        [1130.1595],
#        [1121.665 ],
#        [1120.333 ],
#        [1122.8217],
#        [1122.8612],
#        [1127.1838],
#        [1135.1815],
#        [1150.5294],
#        [1140.569 ],
#        [1136.9124],
#        [1128.715 ],
#        [1126.9629],
#        [1143.4758],
#        [1184.6161],
#        [1205.7719],
#        [1222.2573],
#        [1249.452 ],
#        [1259.5854],
#        [1271.8962],
#        [1259.749 ],
#        [1247.6859],
#        [1225.8309],
#        [1190.8427],
#        [1156.1372],
#        [1139.806 ],
#        [1131.7208],
#        [1131.2605],
#        [1131.4607],
#        [1123.944 ],
#        [1123.2788],
#        [1122.8472],
#        [1139.871 ],
#        [1192.1401],
#        [1265.3646],
#        [1288.2393],
#        [1301.132 ],
#        [1301.873 ]], dtype=float32)

# %%
# Recover the original prices instead of the scaled version
predicted_prices_googl = scaler.inverse_transform(predicted_googl)
predicted_prices_googl
# Out:
# array([[1216.1567],
#        [1222.9734],
#        [1226.0927],
#        [1224.8828],
#        [1224.0938],
#        [1214.8054],
#        [1214.6385],
#        [1211.8651],
#        [1212.2379],
#        [1211.1627],
#        [1210.3528],
#        [1211.7633],
#        [1205.4146],
#        [1192.2654],
#        [1181.8627],
#        [1177.9335],
#        [1182.3695],
#        [1179.3096],
#        [1179.7765],
#        [1191.8745],
#        [1194.1731],
#        [1197.0349],
#        [1188.1594],
#        [1196.2643],
#        [1211.2277],
#        [1216.1155],
#        [1223.5806],
#        [1222.7766],
#        [1226.7257],
#        [1232.1426],
#        [1228.8444],
#        [1224.1404],
#        [1216.5742],
#        [1221.3322],
#        [1228.3322],
#        [1235.6154],
#        [1232.869 ],
#        [1240.6627],
#        [1239.9015],
#        [1236.0995],
#        [1244.4489],
#        [1248.7139],
#        [1247.5319],
#        [1244.8842],
#        [1242.0511],
#        [1240.3665],
#        [1244.1179],
#        [1246.8904],
#        [1247.208 ],
#        [1250.3743],
#        [1246.2401],
#        [1241.9482],
#        [1245.4006],
#        [1248.2787],
#        [1247.081 ],
#        [1236.1995],
#        [1228.5251],
#        [1229.5448],
#        [1242.2799],
#        [1250.9249],
#        [1250.2046],
#        [1256.155 ],
#        [1258.5453],
#        [1259.6566],
#        [1255.8715],
#        [1258.2533],
#        [1253.2272],
#        [1257.7029],
#        [1263.0403],
#        [1253.7974],
#        [1255.6099],
#        [1254.8835],
#        [1255.4249],
#        [1257.4117]], dtype=float32)

# %%
real_prices_fb = scaler.inverse_transform(y_fb_test.reshape(-1, 1))
real_prices_aapl = scaler.inverse_transform(y_aapl_test.reshape(-1, 1))
real_prices_amzn = scaler.inverse_transform(y_amzn_test.reshape(-1, 1))
real_prices_nflx = scaler.inverse_transform(y_nflx_test.reshape(-1, 1))
real_prices_googl = scaler.inverse_transform(y_googl_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
fb_stocks = pd.DataFrame({
    "Real": real_prices_fb.ravel(),
    "Predicted": predicted_prices_fb.ravel()
})
fb_stocks.head(10)
# Out:
#           Real    Predicted
# 0  1252.444901  1260.327393
# 1  1261.880601  1268.744507
# 2  1261.930790  1269.374146
# 3  1272.069148  1267.565063
# 4  1270.814401  1268.745850
# 5  1255.506485  1270.082397
# 6  1227.603917  1266.724609
# 7  1235.079199  1261.030396
# 8  1221.929448  1252.883179
# 9  1206.420772  1243.105103

# %%
# Create a DataFrame of Real and Predicted values
aapl_stocks = pd.DataFrame({
    "Real": real_prices_aapl.ravel(),
    "Predicted": predicted_prices_aapl.ravel()
})
aapl_stocks.head(10)
# Out:
#           Real    Predicted
# 0  1198.770185  1184.940918
# 1  1200.478164  1184.775269
# 2  1205.306051  1185.682861
# 3  1201.161356  1188.213135
# 4  1193.737341  1191.380981
# 5  1195.991873  1191.288208
# 6  1193.714568  1187.689087
# 7  1201.252448  1186.195679
# 8  1198.747412  1188.620361
# 9  1196.379015  1190.861694

# %%
# Create a DataFrame of Real and Predicted values
amzn_stocks = pd.DataFrame({
    "Real": real_prices_amzn.ravel(),
    "Predicted": predicted_prices_amzn.ravel()
})
amzn_stocks.head(10)
# Out:
#           Real    Predicted
# 0  1204.207983  1247.719971
# 1  1214.890549  1245.907837
# 2  1211.156476  1244.721924
# 3  1214.088799  1239.322388
# 4  1194.304895  1234.058105
# 5  1186.435875  1223.197021
# 6  1155.293858  1218.355347
# 7  1174.402214  1210.762085
# 8  1153.645818  1206.005249
# 9  1143.052335  1198.543091

# %%
# Create a DataFrame of Real and Predicted values
nflx_stocks = pd.DataFrame({
    "Real": real_prices_nflx.ravel(),
    "Predicted": predicted_prices_nflx.ravel()
})
nflx_stocks.head(10)
# Out:
#           Real    Predicted
# 0  1137.499333  1133.034180
# 1  1147.952123  1129.140137
# 2  1130.910608  1124.054321
# 3  1118.302859  1122.281494
# 4  1079.092514  1123.615723
# 5  1067.004928  1125.967041
# 6  1039.040000  1134.222168
# 7  1064.230727  1144.028564
# 8  1060.738208  1156.957031
# 9  1060.118967  1167.538940

# %%
# Create a DataFrame of Real and Predicted values
googl_stocks = pd.DataFrame({
    "Real": real_prices_googl.ravel(),
    "Predicted": predicted_prices_googl.ravel()
})
googl_stocks.head(10)
# Out:
#       Real    Predicted
# 0  1231.22  1216.156738
# 1  1229.87  1222.973389
# 2  1233.26  1226.092651
# 3  1238.76  1224.882812
# 4  1229.53  1224.093750
# 5  1234.49  1214.805420
# 6  1218.12  1214.638550
# 7  1246.61  1211.865112
# 8  1241.42  1212.237915
# 9  1226.15  1211.162720

# %%
# Plot the real vs predicted prices as a line chart
fb_stocks.plot(title = "fb")

# %%
# Plot the real vs predicted prices as a line chart
aapl_stocks.plot(title = "aapl")

# %%
# Plot the real vs predicted prices as a line chart
amzn_stocks.plot(title = "amzn")

# %%
# Plot the real vs predicted prices as a line chart
nflx_stocks.plot(title = "nflx")

# %%
# Plot the real vs predicted prices as a line chart
googl_stocks.plot(title = "googl")
