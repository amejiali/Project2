# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
from sklearn import preprocessing

# %%
#Reading the .csv files

fb_csv = Path("../Resources/fb_data.csv")
fb_df = pd.read_csv(fb_csv)

aapl_csv = Path("../Resources/aapl_data.csv")
aapl_df = pd.read_csv(aapl_csv)

amzn_csv = Path("../Resources/amzn_data.csv")
amzn_df = pd.read_csv(amzn_csv)

nflx_csv = Path("../Resources/nflx_data.csv")
nflx_df = pd.read_csv(nflx_csv)

googl_csv = Path("../Resources/googl_data.csv")
googl_df = pd.read_csv(googl_csv)

# %%
#Calculating Volatility = abs(Close - Open) * Volume in a 0-1 Scale

fb_df["Volatility"] = abs(fb_df.Close - fb_df.Open) * fb_df.Volume
x = fb_df.Volatility.values #returns a numpy array
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
df = pd.DataFrame(x_scaled)
fb_df["Volatility"] = df

aapl_df["Volatility"] = abs(aapl_df.Close - aapl_df.Open) * aapl_df.Volume
x = aapl_df.Volatility.values #returns a numpy array
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
df = pd.DataFrame(x_scaled)
aapl_df["Volatility"] = df

amzn_df["Volatility"] = abs(amzn_df.Close - amzn_df.Open) * amzn_df.Volume
x = amzn_df.Volatility.values #returns a numpy array
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
df = pd.DataFrame(x_scaled)
amzn_df["Volatility"] = df

nflx_df["Volatility"] = abs(nflx_df.Close - nflx_df.Open) * nflx_df.Volume
x = nflx_df.Volatility.values #returns a numpy array
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
df = pd.DataFrame(x_scaled)
nflx_df["Volatility"] = df

googl_df["Volatility"] = abs(googl_df.Close - googl_df.Open) * googl_df.Volume
x = googl_df.Volatility.values #returns a numpy array
x = x.reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x_scaled
df = pd.DataFrame(x_scaled)
googl_df["Volatility"] = df

# %%
fb_df.head()
# Out:
#          Date    Open    High     Low     Close    Volume  Volatility
# 0  2019-01-02  128.99  137.51  128.56  135.4100  25465924    0.286522
# 1  2019-01-03  134.69  137.17  131.12  131.8902  18011900    0.088181
# 2  2019-01-04  134.01  138.00  133.75  137.9400  23927539    0.164677
# 3  2019-01-07  137.45  138.87  135.91  138.2300  16261533    0.021965
# 4  2019-01-08  139.89  143.14  139.54  142.5843  22239823    0.104831

# %%
aapl_df.head()
# Out:
#          Date    Open      High     Low     Close    Volume  Volatility
# 0  2019-01-02  154.89  158.8500  154.23  157.5225  27803621    0.214265
# 1  2019-01-03  143.98  145.7200  142.00  142.2900  82418448    0.407750
# 2  2019-01-04  144.53  148.5499  143.80  148.1200  51267225    0.538786
# 3  2019-01-07  148.70  148.8300  145.90  147.9100  49982480    0.115592
# 4  2019-01-08  149.56  151.8200  148.52  150.6300  36592406    0.114619

# %%
amzn_df.head()
# Out:
#          Date     Open     High        Low     Close   Volume  Volatility
# 0  2019-01-02  1465.20  1553.36  1460.9300  1536.730  7132821    0.902244
# 1  2019-01-03  1520.01  1538.00  1498.1062  1502.070  6340704    0.200930
# 2  2019-01-04  1530.00  1594.00  1518.3100  1574.540  8285596    0.652522
# 3  2019-01-07  1602.31  1634.56  1589.1850  1631.120  7252880    0.369340
# 4  2019-01-08  1664.69  1676.61  1616.6100  1655.835  8184304    0.127908

# %%
nflx_df.head()
# Out:
#          Date    Open      High     Low   Close    Volume  Volatility
# 0  2019-01-02  259.28  269.7499  256.58  267.67  10715228    0.114250
# 1  2019-01-03  270.20  275.7900  264.43  271.91  13801524    0.029993
# 2  2019-01-04  281.88  297.8000  278.54  297.47  18127036    0.359141
# 3  2019-01-07  302.10  316.8000  301.65  316.63  17137501    0.316450
# 4  2019-01-08  319.98  320.5100  308.01  320.39  14085038    0.007339

# %%
googl_df.head()
# Out:
#          Date     Open     High        Low     Close   Volume  Volatility
# 0  2019-01-02  1027.20  1060.79  1025.2750  1053.240  1346501    0.279226
# 1  2019-01-03  1050.67  1066.26  1022.3700  1026.505  1546910    0.297727
# 2  2019-01-04  1041.63  1080.00  1036.8600  1076.550  1792417    0.498923
# 3  2019-01-07  1080.97  1082.70  1062.6400  1076.010  1872050    0.073502
# 4  2019-01-08  1084.77  1093.35  1068.3486  1085.510  1402631    0.007682

# %%
fb_df.Volatility.hvplot()
# Out:
# :Curve   [index]   (Volatility)

# %%
aapl_df.Volatility.hvplot()
# Out:
# :Curve   [index]   (Volatility)

# %%
amzn_df.Volatility.hvplot()
# Out:
# :Curve   [index]   (Volatility)

# %%
nflx_df.Volatility.hvplot()
# Out:
# :Curve   [index]   (Volatility)

# %%
googl_df.Volatility.hvplot()
# Out:
# :Curve   [index]   (Volatility)

# %%
#Saving data to .csv files
fb_df.to_csv("../Resources/fb_data.csv", encoding='utf-8', index = False)
amzn_df.to_csv("../Resources/amzn_data.csv", encoding='utf-8', index = False)
aapl_df.to_csv("../Resources/aapl_data.csv", encoding='utf-8', index = False)
nflx_df.to_csv("../Resources/nflx_data.csv", encoding='utf-8', index = False)
googl_df.to_csv("../Resources/googl_data.csv", encoding='utf-8', index = False)
